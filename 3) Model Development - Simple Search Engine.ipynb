# %% [markdown]
# # Importing Packages:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re

warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# # Reading cleaned dataset :

# %%
df = pd.read_csv('cleaned_dataset.csv')

# %%
df.drop("Unnamed: 0" , inplace = True , axis = 1)

# %%
df.head(30)
# Out:
#                                            title  \
# 0                                         Gilead
# 1                                   Spider's Web
# 2                                   The One Tree
# 3                                 Rage of angels
# 4                                 The Four Loves
# 5                            The Problem of Pain
# 6                               An Autobiography
# 7                         Empires of the Monsoon
# 8                           The Gap Into Madness
# 9                             Master of the Game
# 10                             If Tomorrow Comes
# 11                         Assassin's Apprentice
# 12                           Warhost of Vastmark
# 13                      The Once and Future King
# 14                               Murder in LaMut
# 15                                Jimmy the Hand
# 16                              Well of Darkness
# 17  Witness for the Prosecution & Selected Plays
# 18                              The Little House
# 19                                Mystical Paths
# 20                             Glittering Images
# 21                              Glamorous Powers
# 22                                  The Mad Ship
# 23                                  Post Captain
# 24                      The Reverse of the Medal
# 25                                   Miss Marple
# 26                    The Years of Rice and Salt
# 27                                        Spares
# 28                                       Gravity
# 29                                The Wise Woman
#
#                                           subtitle  \
# 0                                          A Novel
# 1                                          A Novel
# 2                                          A Novel
# 3                                          A Novel
# 4                                          A Novel
# 5                                          A Novel
# 6                                          A Novel
# 7   A History of the Indian Ocean and Its Invaders
# 8                                  Chaos and Order
# 9                                          A Novel
# 10                                         A Novel
# 11                                         A Novel
# 12                                         A Novel
# 13                                         A Novel
# 14                                         A Novel
# 15                                         A Novel
# 16                                         A Novel
# 17                                         A Novel
# 18                                         A Novel
# 19                                         A Novel
# 20                                         A Novel
# 21                                         A Novel
# 22                                         A Novel
# 23                                         A Novel
# 24                                         A Novel
# 25                      The Complete Short Stories
# 26                                         A Novel
# 27                                         A Novel
# 28                                         A Novel
# 29                                         A Novel
#
#                             authors                              categories  \
# 0                Marilynne Robinson                                 Fiction
# 1   Charles Osborne;Agatha Christie           Detective and mystery stories
# 2              Stephen R. Donaldson                        American fiction
# 3                    Sidney Sheldon                                 Fiction
# 4               Clive Staples Lewis                          Christian life
# 5               Clive Staples Lewis                          Christian life
# 6                   Agatha Christie                        Authors, English
# 7                      Richard Hall                            Africa, East
# 8              Stephen R. Donaldson     Hyland, Morn (Fictitious character)
# 9                    Sidney Sheldon                       Adventure stories
# 10                   Sidney Sheldon                       Adventure stories
# 11                       Robin Hobb                        American fiction
# 12                      Janny Wurts                                 Fiction
# 13            Terence Hanbury White                      Arthurian romances
# 14  Raymond E. Feist;Joel Rosenberg                       Adventure stories
# 15  Raymond E. Feist;S. M. Stirling                         Fantasy fiction
# 16      Margaret Weis;Tracy Hickman                                 Fiction
# 17                  Agatha Christie                           English drama
# 18                 Philippa Gregory                            Country life
# 19                    Susan Howatch                         English fiction
# 20                    Susan Howatch                         English fiction
# 21                    Susan Howatch                                  Clergy
# 22                       Robin Hobb                         Fantasy fiction
# 23                  Patrick O'Brian     Aubrey, Jack (Fictitious character)
# 24                  Patrick O'Brian                       Adventure stories
# 25                  Agatha Christie  Detective and mystery stories, English
# 26             Kim Stanley Robinson                             Black Death
# 27           Michael Marshall Smith                           Human cloning
# 28                   Tess Gerritsen                         Science fiction
# 29                 Philippa Gregory                           Great Britain
#
#                                           description  published_year  \
# 0   A NOVEL THAT READERS and critics have been eag...          2004.0
# 1   A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2   Volume Two of Stephen Donaldson's acclaimed se...          1982.0
# 3   A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 4   Lewis' work on the nature of love divides love...          2002.0
# 5   "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# 6                                           Donation.          1977.0
# 7   Until Vasco da Gama discovered the sea-route t...          1998.0
# 8   A new-cover reissue of the fourth book in the ...          1994.0
# 9   Kate Blackwell is an enigma and one of the mos...          1982.0
# 10  One of Sidney Sheldon's most popular and bests...          1994.0
# 11                                     Fantasy-roman.          1996.0
# 12  Tricked once more by his wily half-brother, Ly...          1995.0
# 13  An omnibus volume of the author's complete sto...          1996.0
# 14  Available in the U.S. for the first time, this...          2003.0
# 15  Jimmy the Hand, boy thief of Krondor, lived in...          2003.0
# 16  Gareth is just a frightened young lad when he ...          2001.0
# 17  Newly-Jacketed Edition Designed To Celebrate T...          1995.0
# 18  It was easy for Elizabeth. She married the man...          1998.0
# 19  1968 finds Nicholas Darrow wrestling with pers...          1996.0
# 20  It is 1937, and Charles Ashworth, a Canon to t...          1996.0
# 21  Reissue of the author's most famous and well-l...          1996.0
# 22  Fantasy master Robin Hobb delivers the stunnin...          2000.0
# 23  This tale begins with Jack Aubrey arriving hom...          1996.0
# 24  In this book, Jack Aubrey returns from his dut...          1997.0
# 25  Miss Marple featured in 20 short stories, publ...          1997.0
# 26  Hailed by "The New York Times Book Review" as ...          2003.0
# 27  Spares - human clones, the ultimate health ins...          1998.0
# 28  Emma Watson a research physician has been trai...          2004.0
# 29  Alone and vulnerable, Alys joins a nunnery in ...          2002.0
#
#     average_rating  num_pages  ratings_count
# 0             3.85      247.0          361.0
# 1             3.83      241.0         5164.0
# 2             3.97      479.0          172.0
# 3             3.93      512.0        29532.0
# 4             4.15      170.0        33684.0
# 5             4.09      176.0        37569.0
# 6             4.27      560.0         3975.0
# 7             4.41      608.0           65.0
# 8             4.15      743.0          103.0
# 9             4.11      489.0        43540.0
# 10            4.04      501.0        49170.0
# 11            4.15      460.0       133972.0
# 12            4.03      522.0         2966.0
# 13            4.04      823.0         2805.0
# 14            3.70      337.0         5083.0
# 15            3.95      368.0         5579.0
# 16            3.66      599.0           68.0
# 17            4.05      352.0         3908.0
# 18            3.66      368.0         1832.0
# 19            4.23      576.0         1023.0
# 20            4.07      512.0         2045.0
# 21            4.20      512.0         1441.0
# 22            4.24      906.0        36101.0
# 23            4.29      474.0         7815.0
# 24            4.41      261.0          177.0
# 25            4.20      359.0         6235.0
# 26            3.73      772.0          194.0
# 27            4.13      317.0         2481.0
# 28            4.04      342.0         8024.0
# 29            3.31      640.0         6583.0

# %% [markdown]
# # Creating Model :

# %%
vectorizer = TfidfVectorizer()
X_new = vectorizer.fit_transform([x.lower() for x in df['title']])

# %%
query = 'space'
query_vec = vectorizer.transform([query])
similarity = cosine_similarity(query_vec, X_new).flatten()

# %%
test = np.argsort(-similarity) # sorting descending and get the index
result = df.iloc[test]
result['title'].head()
# Out:
# 4535                           Space
# 5086            The Poetics of Space
# 5679              The Crack in Space
# 6494               Ministry of Space
# 4217    The Nature of Space and Time
# Name: title, dtype: object

# %%
len(result)
# Out:
# 6810

# %% [markdown]
# # Better Model :

# %%
match_idx = np.where(similarity != 0)[0]
indices = np.argsort(-similarity[match_idx])
correct_indices = match_idx[indices]
result = df.iloc[correct_indices]

result['title'].head()
# Out:
# 4535                           Space
# 5086            The Poetics of Space
# 5679              The Crack in Space
# 6494               Ministry of Space
# 4217    The Nature of Space and Time
# Name: title, dtype: object

# %%
df['score'] = np.log(df['average_rating'] *  df['ratings_count'])

# %%
result = df.iloc[correct_indices]
overall = result['score']  * similarity[correct_indices]
result.loc[overall.sort_values(ascending=False).index].head()
# Out:
#                              title subtitle  \
# 5086          The Poetics of Space  A Novel
# 5679            The Crack in Space  A Novel
# 6494             Ministry of Space  A Novel
# 4535                         Space  A Novel
# 5878  Have Space Suit, Will Travel  A Novel
#
#                                     authors   categories  \
# 5086                       Gaston Bachelard   Philosophy
# 5679                         Philip K. Dick      Fiction
# 6494  Warren Ellis;Chris Weston;Laura DePuy  Imperialism
# 4535                  James Albert Michener      Fiction
# 5878                     Robert A. Heinlein      Fiction
#
#                                             description  published_year  \
# 5086  Shows how our perceptions of home shape our th...          1994.0
# 5679  All kinds of problems erupt when a repairman d...          1966.0
# 6494  In this alternative history tale, the British ...          2005.0
# 4535                       No Description For that book          1992.0
# 5878  Teenager Clifford "Kip" Russell wins second pr...          2005.0
#
#       average_rating  num_pages  ratings_count      score
# 5086            4.19      282.0         6625.0  10.231306
# 5679            3.46      188.0         1791.0   8.731798
# 6494            3.71      100.0         1298.0   8.479612
# 4535            3.97      815.0           35.0   4.934114
# 5878            3.89      276.0        22399.0  11.375181

# %% [markdown]
# # Function to get them all :

# %%
def search_engine(word, limit=5):
    word = re.sub('[^a-zA-Z0-9 ]','', word.lower()) # match everyting that's not alphabet and digit and remove it
    query_vec = vectorizer.transform([word])
    similarity = cosine_similarity(query_vec, X_new).flatten()
    
    filtered = np.where(similarity != 0)[0]
    indices = np.argsort(-similarity[filtered])
    correct_indices = filtered[indices]
    result = df.iloc[correct_indices]
    
    if not len(result):
        return 'result not found'
    
    overall =  result['score'] *  similarity[correct_indices] 
    
    return result.loc[overall.sort_values(ascending=False).index].head(limit)

# %%
search_engine('fiction')
# Out:
#                                        title  \
# 4005                      The Art of Fiction
# 1196                Complete Shorter Fiction
# 1275                             Non-Fiction
# 6261  Write Great Fiction - Plot & Structure
# 2435   The Norton Anthology of Short Fiction
#
#                               subtitle                               authors  \
# 4005  Notes on Craft for Young Writers                          John Gardner
# 1196                           A Novel                           Oscar Wilde
# 1275                           A Novel                       Chuck Palahniuk
# 6261                           A Novel                      James Scott Bell
# 2435                           A Novel  Ronald Verlin Cassill;Richard Bausch
#
#                        categories  \
# 4005  Language Arts & Disciplines
# 1196                      Fiction
# 1275      Curiosities and wonders
# 6261  Language Arts & Disciplines
# 2435                      Fiction
#
#                                             description  published_year  \
# 4005  A guide to creative writing examines diverse f...          1991.0
# 1196  For the first time in one volume, this complet...          1998.0
# 1275  Chuck Palahniuk's world has been, well, differ...          2004.0
# 6261  Craft an Engaging Plot How does plot influence...          2004.0
# 2435  The classroom standard for readers and aspirin...          2006.0
#
#       average_rating  num_pages  ratings_count     score
# 4005            4.00      224.0         4877.0  9.878580
# 1196            4.16      288.0         1167.0  8.487707
# 1275            3.57      233.0          212.0  6.629152
# 6261            4.10      234.0         4304.0  9.778287
# 2435            4.17     1776.0          645.0  7.897166
